# %%
<!DOCTYPE html>
<html>
<head>
  <title>Bootstrap Layout Example</title>
  <link rel="stylesheet" href="https://maxcdn.bootstrapcdn.com/bootstrap/4.5.0/css/bootstrap.min.css">
  <style>
    .jumbotron {
      background-image: url("C:\Users\apurv\Downloads\download.jpeg");
      background-size: cover;
      color: white;
      text-align: center;
      padding: 100px;
      margin-bottom: 0;
    }

    .feature {
      padding: 50px;
      text-align: center;
      background-color: #f8f9fa;
    }

    .feature i {
      font-size: 48px;
      color: #007bff;
    }

    .feature h3 {
      margin-top: 20px;
    }

    .testimonial {
      text-align: center;
      margin-top: 50px;
      margin-bottom: 50px;
    }

    .testimonial img {
      width: 100px;
      border-radius: 50%;
    }

    .testimonial p {
      margin-top: 20px;
    }

    .footer {
      background-color: #343a40;
      padding: 20px;
      color: white;
      text-align: center;
    }
  </style>
</head>
<body>
  <header>
    <nav class="navbar navbar-expand-lg navbar-dark bg-dark">
      <a class="navbar-brand" href="#">NewsAI</a>
      <button class="navbar-toggler" type="button" data-toggle="collapse" data-target="#navbarNav" aria-controls="navbarNav" aria-expanded="false" aria-label="Toggle navigation">
        <span class="navbar-toggler-icon"></span>
      </button>
      <div class="collapse navbar-collapse" id="navbarNav">
        <ul class="navbar-nav ml-auto">
          <li class="nav-item active">
            <a class="nav-link" href="#">Home</a>
          </li>
          <li class="nav-item">
            <a class="nav-link" href="#">About</a>
          </li>
          <li class="nav-item">
            <a class="nav-link" href="#">Services</a>
          </li>
          <li class="nav-item">
            <a class="nav-link" href="#">Contact</a>
          </li>
        </ul>
      </div>
    </nav>
    <div class="jumbotron">
      <h1>Welcome to NewsAI</h1>
      <p>We have all the recent and important news related to artificial intelligence ready for you.</p>
      <a class="btn btn-primary btn-lg" href="#" role="button">Learn More about AI</a>
    </div>
  </header>


  <div class="row my-5 pt-3">
    <div class="col-12 col-md-4 my-2">
        <div class="card shadow h-100">
            <img src="C:\Users\apurv\Downloads\robotic glove.jpeg" alt="news thumbnail" class="card-img-top">
            <div class="card-body">
                <h4 class="card-title">
                    Robotic Glove helps stroke survivors
                </h4>
                <p class="card-text">A new soft robotic glove that helps stroke patients to relearn piano. Researchers and scientists have combined innovative soft robotics with AI to design the new glove</p>
                <a href="#" class="stretched-link"></a>

            </div>


        </div>
    </div>
    <div class="col-12 col-md-4 my-2">
        <div class="card shadow h-100">
            <img src="C:\Users\apurv\Downloads\paytm.jpeg" alt="news thumbnail" class="card-img-top">
            <div class="card-body">
                <h4 class="card-title">
                    Paytm founder on 'superintelligent AI'
                </h4>
                <p class="card-text">Raised his concerns over 'disempowerment of humanity' over a post by ChatGPT creator OpenAI which expressed inability to have a solution fro controlling a super intelligent AI.</p>
                <a href="#" class="stretched-link"></a>

            </div>


        </div>
    </div>
    <div class="col-12 col-md-4 my-2">
        <div class="card shadow h-100">
            <img src="C:\Users\apurv\Downloads\security.jpeg" alt="news thumbnail" class="card-img-top">
            <div class="card-body">
                <h4 class="card-title">
                    Educating national security leaders on AI
                </h4>
                <p class="card-text">Understanding artificial intelligence and how it relates to matters of national security has become a top priority for military and government leaders in recent years</p>
                <a href="#" class="stretched-link"></a>

            </div>


        </div>
    </div>
</div>
<div class="my-5">
    <a href="#" class="text-dark text-right">
        <h5>
            See the news
            <i class="fas fa-arrow-right align-middle"></i>
        </h5>
    </a>

</div>
</div>


  <section class="testimonial">
    <div class="container">
      <div class="row">
        <div class="col-md-6 offset-md-3">
          <img src="C:\Users\apurv\Downloads\john.jpeg" alt="Image of John McCarthy">
          <p>He is the father of Artificial Intelligence and once said that "If it takes 200 years to achieve artificial intelligence, and then finally there is a textbook that explains how its done, the hardest part of that textbook to write will be the part that explains why people didn't think of it 200 years ago...</p>
          <p> -John McCarthy</p>
        </div>
      </div>
    </div>
  </section>

  <footer class="footer">
    <div class="container">
      <p>&copy; Apurva Ninave. All rights reserved.</p>
    </div>
  </footer>

  <script src="https://kit.fontawesome.com/your-font-awesome-kit.js" crossorigin="anonymous"></script>
  <script src="https://code.jquery.com/jquery-3.5.1.slim.min.js"></script>
  <script src="https://cdn.jsdelivr.net/npm/@popperjs/core@2.0.7/dist/umd/popper.min.js"></script>
  <script src="https://maxcdn.bootstrapcdn.com/bootstrap/4.5.0/js/bootstrap.min.js"></script>
</body>
</html>
